# %% [markdown]
# <a href="https://colab.research.google.com/github/rsrohan/Energy-Utilization-of-Rooftops-In-Urban-Areas/blob/datascraping/Datasets/Dataset_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests
from PIL import Image
import urllib.request

link = 'https://mypages.valdosta.edu/rpmihail/skyfinder/images/index.html'
mainpage = requests.get(link)
soup = bs(mainpage.content,'html.parser')

# %%
all_links = soup.find_all('a')
all_links
# Out:
# [<a href="./10066.html">10066</a>,
#  <a href="./10066.zip"> download </a>,
#  <a href="../Masks/10066.png">mask</a>,
#  <a href="./10870.html">10870</a>,
#  <a href="./10870.zip"> download</a>,
#  <a href="../Masks/10870.png">mask</a>,
#  <a href="./10917.html">10917</a>,
#  <a href="./10917.zip"> download</a>,
#  <a href="../Masks/10917.png">mask</a>,
#  <a href="./1093.html">1093</a>,
#  <a href="./1093.zip"> download</a>,
#  <a href="../Masks/1093.png">mask</a>,
#  <a href="./11160.html">11160</a>,
#  <a href="./11160.zip"> download</a>,
#  <a href="../Masks/11160.png">mask</a>,
#  <a href="./11331.html">11331</a>,
#  <a href="./11331.zip"> download</a>,
#  <a href="../Masks/11331.png">mask</a>,
#  <a href="./162.html">162</a>,
#  <a href="./162.zip"> download</a>,
#  <a href="../Masks/162.png">mask</a>,
#  <a href="./17218.html">17218</a>,
#  <a href="./17218.zip"> download</a>,
#  <a href="../Masks/17218.png">mask</a>,
#  <a href="./17244.html">17244</a>,
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
source = 'https://mypages.valdosta.edu/rpmihail/skyfinder/'

#try:
 # !mkdir all_imgs
#except:
 # pass

#%cd 'all_imgs'

for i in range(129,130): 
  if all_links[i].get_text('a') != 'mask' and all_links[i].get_text('a') != ' download' and all_links[i].get_text('a') != ' download ':
    print(all_links[i])
    href_image = all_links[i].get('href')
    href_image = href_image.lstrip('./')
    print(href_image)
    image_link = source + 'images/' + href_image
    print(image_link)
    imagepage = requests.get(image_link)
    print(imagepage)
    soup1 = bs(imagepage.content,'html.parser')
    all_images = soup1.find_all('a')
    for j in range(1000):
      href_subimg = all_images[j].get('href')
      href_subimg = href_subimg.lstrip('./')
      print(href_subimg)
      subimg_link = source + 'images/' + href_subimg
      print(subimg_link)
      img_name = '/content/gdrive/My Drive/minor/dataset/9291/' + all_links[i].get_text('a') + '_' + str(j) + '.png'
      print(img_name)
      with urllib.request.urlopen(subimg_link) as url:
        with open(img_name, 'wb') as f:
        #with open(img_name, 'wb') as f:
          f.write(url.read())
# Out:
# <a href="./9291.html">9291</a>
# 9291.html
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291.html
# <Response [200]>
# 9291/20140202_024529.jpg
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291/20140202_024529.jpg
# /content/gdrive/My Drive/minor/dataset/9291/9291_0.png
# 9291/20140202_034521.jpg
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291/20140202_034521.jpg
# /content/gdrive/My Drive/minor/dataset/9291/9291_1.png
# 9291/20140202_041521.jpg
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291/20140202_041521.jpg
# /content/gdrive/My Drive/minor/dataset/9291/9291_2.png
# 9291/20140202_054520.jpg
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291/20140202_054520.jpg
# /content/gdrive/My Drive/minor/dataset/9291/9291_3.png
# 9291/20140202_181529.jpg
# https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291/20140202_181529.jpg
# /content/gdrive/My Drive/minor/dataset/9291/9291_4.png
# 9291/20140203_074529.jpg
# ...
